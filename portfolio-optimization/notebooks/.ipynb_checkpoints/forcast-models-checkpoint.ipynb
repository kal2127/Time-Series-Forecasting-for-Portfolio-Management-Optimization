# %%
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
import pmdarima as pm

# 1. We will focus on TSLA for this prediction
tsla_data = cleaned_data['TSLA']

# 2. Split the data: Use 80% for training and 20% for testing
train_size = int(len(tsla_data) * 0.8)
train, test = tsla_data[0:train_size], tsla_data[train_size:]

print(f"Training days: {len(train)}")
print(f"Testing days: {len(test)}")
